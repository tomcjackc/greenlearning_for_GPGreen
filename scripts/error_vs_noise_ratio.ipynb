# %%
# %load_ext autoreload
# %autoreload 2

# Import the library
import greenlearning as gl
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Using TensorFlow 2 backend.
#
# WARNING:tensorflow:From /home/users/tc656/miniforge3/envs/greenlearning/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
np.random.seed(42)

N_train = 75
noise_ratio_arr = np.linspace(0, 0.5, 50)[1:] # Avoid noise_ratio = 0 as we've already done that
print(noise_ratio_arr)
resample = 1
repeats = range(5)

for i in repeats:
    for noise_ratio in noise_ratio_arr:

        # Construct neural networks for G and homogeneous solution
        G_network = gl.matrix_networks([2] + [50] * 4 + [1], "rational", (1,1))
        U_hom_network = gl.matrix_networks([1] + [50] * 4 + [1], "rational", (1,))

        # Define the model
        model = gl.Model(G_network, U_hom_network, N_train=N_train, noise_ratio=noise_ratio, resample=resample, repeat=i, adam_steps=10, lbfgs_steps=10)

        # Train the model on the dataset "helmholtz" in the path "examples/datasets/"
        model.train("examples/datasets/","helmholtz")

        # Save the NNs evaluated at a grid in a csv file
        model.save_results()

        # Close the TensorFlow session
        model.sess.close()
# Out:
# It: 0, Loss = 1.201e+00
# INFO:tensorflow:Optimization terminated with:
#   Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#   Objective function value: 0.978047
#   Number of iterations: 10
#   Number of functions evaluations: 13
# G_pred shape (100, 100)

# %%
def relative_L2_error(y_true, y_pred, eps=1e-12):
    """
    Uniform-grid discrete relative L2 error, expressed as a %, averaged over examples on axis=0.
    y_true, y_pred shape: (B, ...grid axes...)
    """
    # reduce over all non-batch axes → per-example norms
    reduce_axes = tuple(range(1, y_true.ndim))
    num = np.sqrt(np.sum((y_pred - y_true)**2, axis=reduce_axes))
    den = np.sqrt(np.sum(y_true**2,          axis=reduce_axes))
    rel = num / (den + eps)          # shape (B,)
    return 100 * np.mean(rel)             # scalar

path = f'examples/datasets/helmholtz.mat'
raw_data = sp.io.loadmat(path)

N_test = 20

# N_train_arr = np.array([1, 5, 10, 15, 20, 25, 30])
N_train = 75
noise_ratio_arr = np.linspace(0, 0.5, 50)
resample = 1
repeats = 5

u = raw_data['F'][::2 * resample, -N_test:] # (100, N_test)
print('u.shape', u.shape)
v = raw_data['U'][::resample, -N_test:] # (100, N_test)
print('v.shape', v.shape)

domain_u = raw_data['X'][::resample, 0] # (100,)
print('domain_u.shape', domain_u.shape)
print('domain_u', domain_u)

df = pd.DataFrame(columns=['N_train', 'noise_ratio', 'resample', 'repeat', 'relative_L2_error'])

for i in range(repeats):
    for noise_ratio in noise_ratio_arr:
        
        G_est = np.genfromtxt('results_csv/Green_helmholtz_rational_0_Ntrain%d_noiseratio%.6f_resample%d_repeat%d.csv' % (N_train, noise_ratio, resample, i), delimiter=',')

        # plt.figure()
        # plt.imshow(G_est, extent=(domain_u.min(), domain_u.max(), domain_u.min(), domain_u.max()))
        # plt.colorbar()
        # plt.title('Estimated Green\'s function')
        # plt.show()

        integrand = G_est[:, :, None] * u[:, None, :]  # (100, 100, N_test)  # broadcast u over columns (y-axis)
        v_est = np.trapz(integrand, x=domain_u, axis=0) # (100, N_test)  # integrate over y (axis=1)

        # test_idx = 0
        # fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        # axs[0].plot(domain_u, u[:, test_idx], label='$u$ (source term)')
        # # axs[0].set_title('u')
        # axs[0].legend()
        # axs[1].plot(domain_u, v[:, test_idx], label='$v$ true')
        # axs[1].plot(domain_u, v_est[:, test_idx], '--', label='$v$ pred')
        # # axs[1].set_title('v')
        # axs[1].legend()
        # plt.show()

        vT = v.T
        v_estT = v_est.T

        error = relative_L2_error(vT, v_estT)

        print(f'noise_ratio: {noise_ratio}, repeat: {i}, relative L2 error: {error:f}%')
        df = pd.concat((df, pd.DataFrame({'N_train': [N_train], 'noise_ratio': [noise_ratio], 'resample': [resample], 'repeat': [i], 'relative_L2_error': [error]})), ignore_index=True)

df.to_csv('results/error_vs_noise_ratio.csv', index=False)
# Out:
# u.shape (100, 20)
# v.shape (100, 20)
# domain_u.shape (100,)
# domain_u [0.         0.01010101 0.02020202 0.03030303 0.04040404 0.05050505
#  0.06060606 0.07070707 0.08080808 0.09090909 0.1010101  0.11111111
#  0.12121212 0.13131313 0.14141414 0.15151515 0.16161616 0.17171717
#  0.18181818 0.19191919 0.2020202  0.21212121 0.22222222 0.23232323
#  0.24242424 0.25252525 0.26262626 0.27272727 0.28282828 0.29292929
#  0.3030303  0.31313131 0.32323232 0.33333333 0.34343434 0.35353535
#  0.36363636 0.37373737 0.38383838 0.39393939 0.4040404  0.41414141
#  0.42424242 0.43434343 0.44444444 0.45454545 0.46464646 0.47474747
#  0.48484848 0.49494949 0.50505051 0.51515152 0.52525253 0.53535354
#  0.54545455 0.55555556 0.56565657 0.57575758 0.58585859 0.5959596
#  0.60606061 0.61616162 0.62626263 0.63636364 0.64646465 0.65656566
#  0.66666667 0.67676768 0.68686869 0.6969697  0.70707071 0.71717172
#  0.72727273 0.73737374 0.74747475 0.75757576 0.76767677 0.77777778
#  0.78787879 0.7979798  0.80808081 0.81818182 0.82828283 0.83838384
#  0.84848485 0.85858586 0.86868687 0.87878788 0.88888889 0.8989899
#  0.90909091 0.91919192 0.92929293 0.93939394 0.94949495 0.95959596
#  0.96969697 0.97979798 0.98989899 1.        ]
# /tmp/ipykernel_1150915/1312664607.py:47: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   v_est = np.trapz(integrand, x=domain_u, axis=1) # (100, N_test)  # integrate over y (axis=1)
# /tmp/ipykernel_1150915/1312664607.py:66: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat((df, pd.DataFrame({'N_train': [N_train], 'noise_ratio': [noise_ratio], 'resample': [resample], 'repeat': [i], 'relative_L2_error': [error]})), ignore_index=True)
# noise_ratio: 0.0, repeat: 0, relative L2 error: 7.851428%
# noise_ratio: 0.01020408163265306, repeat: 0, relative L2 error: 7.866890%
# noise_ratio: 0.02040816326530612, repeat: 0, relative L2 error: 7.916952%
# noise_ratio: 0.030612244897959183, repeat: 0, relative L2 error: 8.106990%
# noise_ratio: 0.04081632653061224, repeat: 0, relative L2 error: 7.967301%
# noise_ratio: 0.0510204081632653, repeat: 0, relative L2 error: 8.536840%
# noise_ratio: 0.061224489795918366, repeat: 0, relative L2 error: 8.415445%
# noise_ratio: 0.07142857142857142, repeat: 0, relative L2 error: 8.540223%
# noise_ratio: 0.08163265306122448, repeat: 0, relative L2 error: 8.380106%
# noise_ratio: 0.09183673469387754, repeat: 0, relative L2 error: 8.445094%
# noise_ratio: 0.1020408163265306, repeat: 0, relative L2 error: 9.251093%
# noise_ratio: 0.11224489795918366, repeat: 0, relative L2 error: 8.850488%
# noise_ratio: 0.12244897959183673, repeat: 0, relative L2 error: 9.226931%
# noise_ratio: 0.13265306122448978, repeat: 0, relative L2 error: 10.187003%
# noise_ratio: 0.14285714285714285, repeat: 0, relative L2 error: 8.845363%
# noise_ratio: 0.1530612244897959, repeat: 0, relative L2 error: 9.139958%
# noise_ratio: 0.16326530612244897, repeat: 0, relative L2 error: 9.238792%
# noise_ratio: 0.17346938775510204, repeat: 0, relative L2 error: 9.366289%
# noise_ratio: 0.18367346938775508, repeat: 0, relative L2 error: 9.833651%
# noise_ratio: 0.19387755102040816, repeat: 0, relative L2 error: 44.051944%
# noise_ratio: 0.2040816326530612, repeat: 0, relative L2 error: 53.737796%
# noise_ratio: 0.21428571428571427, repeat: 0, relative L2 error: 9.736037%
# noise_ratio: 0.22448979591836732, repeat: 0, relative L2 error: 59.342273%
# noise_ratio: 0.2346938775510204, repeat: 0, relative L2 error: 10.590209%
# noise_ratio: 0.24489795918367346, repeat: 0, relative L2 error: 13.583812%
# noise_ratio: 0.25510204081632654, repeat: 0, relative L2 error: 10.730542%
# noise_ratio: 0.26530612244897955, repeat: 0, relative L2 error: 13.710205%
# noise_ratio: 0.2755102040816326, repeat: 0, relative L2 error: 59.164740%
# noise_ratio: 0.2857142857142857, repeat: 0, relative L2 error: 77.637801%
# noise_ratio: 0.29591836734693877, repeat: 0, relative L2 error: 73.646932%
# noise_ratio: 0.3061224489795918, repeat: 0, relative L2 error: 64.672781%
# noise_ratio: 0.31632653061224486, repeat: 0, relative L2 error: 97.627256%
# noise_ratio: 0.32653061224489793, repeat: 0, relative L2 error: 69.411614%
# noise_ratio: 0.336734693877551, repeat: 0, relative L2 error: 47.174181%
# noise_ratio: 0.3469387755102041, repeat: 0, relative L2 error: 90.100904%
# noise_ratio: 0.3571428571428571, repeat: 0, relative L2 error: 92.187454%
# noise_ratio: 0.36734693877551017, repeat: 0, relative L2 error: 121.365573%
# noise_ratio: 0.37755102040816324, repeat: 0, relative L2 error: 118.688053%
# noise_ratio: 0.3877551020408163, repeat: 0, relative L2 error: 143.010489%
# noise_ratio: 0.39795918367346933, repeat: 0, relative L2 error: 96.774196%
# noise_ratio: 0.4081632653061224, repeat: 0, relative L2 error: 104.553824%
# noise_ratio: 0.4183673469387755, repeat: 0, relative L2 error: 76.111541%
# noise_ratio: 0.42857142857142855, repeat: 0, relative L2 error: 126.039128%
# noise_ratio: 0.4387755102040816, repeat: 0, relative L2 error: 187.987390%
# noise_ratio: 0.44897959183673464, repeat: 0, relative L2 error: 129.899142%
# noise_ratio: 0.4591836734693877, repeat: 0, relative L2 error: 71.045105%
# noise_ratio: 0.4693877551020408, repeat: 0, relative L2 error: 117.241971%
# noise_ratio: 0.47959183673469385, repeat: 0, relative L2 error: 100.307778%
# noise_ratio: 0.4897959183673469, repeat: 0, relative L2 error: 14.922340%
# noise_ratio: 0.5, repeat: 0, relative L2 error: 126.472758%
# noise_ratio: 0.0, repeat: 1, relative L2 error: 7.848369%
# noise_ratio: 0.01020408163265306, repeat: 1, relative L2 error: 7.888172%
# noise_ratio: 0.02040816326530612, repeat: 1, relative L2 error: 8.034191%
# noise_ratio: 0.030612244897959183, repeat: 1, relative L2 error: 97.456297%
# noise_ratio: 0.04081632653061224, repeat: 1, relative L2 error: 7.939600%
# noise_ratio: 0.0510204081632653, repeat: 1, relative L2 error: 8.110045%
# noise_ratio: 0.061224489795918366, repeat: 1, relative L2 error: 8.225817%
# noise_ratio: 0.07142857142857142, repeat: 1, relative L2 error: 8.506253%
# noise_ratio: 0.08163265306122448, repeat: 1, relative L2 error: 8.043574%
# noise_ratio: 0.09183673469387754, repeat: 1, relative L2 error: 8.755976%
# noise_ratio: 0.1020408163265306, repeat: 1, relative L2 error: 8.751711%
# noise_ratio: 0.11224489795918366, repeat: 1, relative L2 error: 9.271278%
# noise_ratio: 0.12244897959183673, repeat: 1, relative L2 error: 8.732412%
# noise_ratio: 0.13265306122448978, repeat: 1, relative L2 error: 9.244693%
# noise_ratio: 0.14285714285714285, repeat: 1, relative L2 error: 10.404275%
# noise_ratio: 0.1530612244897959, repeat: 1, relative L2 error: 9.153990%
# noise_ratio: 0.16326530612244897, repeat: 1, relative L2 error: 9.582313%
# noise_ratio: 0.17346938775510204, repeat: 1, relative L2 error: 9.829665%
# noise_ratio: 0.18367346938775508, repeat: 1, relative L2 error: 9.821846%
# noise_ratio: 0.19387755102040816, repeat: 1, relative L2 error: 10.115412%
# noise_ratio: 0.2040816326530612, repeat: 1, relative L2 error: 9.165921%
# noise_ratio: 0.21428571428571427, repeat: 1, relative L2 error: 9.473791%
# noise_ratio: 0.22448979591836732, repeat: 1, relative L2 error: 57.419475%
# noise_ratio: 0.2346938775510204, repeat: 1, relative L2 error: 49.910656%
# noise_ratio: 0.24489795918367346, repeat: 1, relative L2 error: 73.068516%
# noise_ratio: 0.25510204081632654, repeat: 1, relative L2 error: 52.517107%
# noise_ratio: 0.26530612244897955, repeat: 1, relative L2 error: 75.024361%
# noise_ratio: 0.2755102040816326, repeat: 1, relative L2 error: 14.336300%
# noise_ratio: 0.2857142857142857, repeat: 1, relative L2 error: 104.321355%
# noise_ratio: 0.29591836734693877, repeat: 1, relative L2 error: 12.595770%
# noise_ratio: 0.3061224489795918, repeat: 1, relative L2 error: 86.945941%
# noise_ratio: 0.31632653061224486, repeat: 1, relative L2 error: 66.660398%
# noise_ratio: 0.32653061224489793, repeat: 1, relative L2 error: 11.518282%
# noise_ratio: 0.336734693877551, repeat: 1, relative L2 error: 89.686944%
# noise_ratio: 0.3469387755102041, repeat: 1, relative L2 error: 110.081223%
# noise_ratio: 0.3571428571428571, repeat: 1, relative L2 error: 79.518528%
# noise_ratio: 0.36734693877551017, repeat: 1, relative L2 error: 99.650281%
# noise_ratio: 0.37755102040816324, repeat: 1, relative L2 error: 146.673714%
# noise_ratio: 0.3877551020408163, repeat: 1, relative L2 error: 103.437036%
# noise_ratio: 0.39795918367346933, repeat: 1, relative L2 error: 81.463534%
# noise_ratio: 0.4081632653061224, repeat: 1, relative L2 error: 99.752326%
# noise_ratio: 0.4183673469387755, repeat: 1, relative L2 error: 128.091096%
# noise_ratio: 0.42857142857142855, repeat: 1, relative L2 error: 110.470251%
# noise_ratio: 0.4387755102040816, repeat: 1, relative L2 error: 71.542303%
# noise_ratio: 0.44897959183673464, repeat: 1, relative L2 error: 116.659686%
# noise_ratio: 0.4591836734693877, repeat: 1, relative L2 error: 98.265160%
# noise_ratio: 0.4693877551020408, repeat: 1, relative L2 error: 156.044340%
# noise_ratio: 0.47959183673469385, repeat: 1, relative L2 error: 116.941166%
# noise_ratio: 0.4897959183673469, repeat: 1, relative L2 error: 201.142627%
# noise_ratio: 0.5, repeat: 1, relative L2 error: 186.042569%
# noise_ratio: 0.0, repeat: 2, relative L2 error: 7.894334%
# noise_ratio: 0.01020408163265306, repeat: 2, relative L2 error: 7.848128%
# noise_ratio: 0.02040816326530612, repeat: 2, relative L2 error: 7.901369%
# noise_ratio: 0.030612244897959183, repeat: 2, relative L2 error: 8.138724%
# noise_ratio: 0.04081632653061224, repeat: 2, relative L2 error: 8.229302%
# noise_ratio: 0.0510204081632653, repeat: 2, relative L2 error: 8.233499%
# noise_ratio: 0.061224489795918366, repeat: 2, relative L2 error: 8.113135%
# noise_ratio: 0.07142857142857142, repeat: 2, relative L2 error: 8.015053%
# noise_ratio: 0.08163265306122448, repeat: 2, relative L2 error: 8.351922%
# noise_ratio: 0.09183673469387754, repeat: 2, relative L2 error: 24.450760%
# noise_ratio: 0.1020408163265306, repeat: 2, relative L2 error: 8.831509%
# noise_ratio: 0.11224489795918366, repeat: 2, relative L2 error: 8.865377%
# noise_ratio: 0.12244897959183673, repeat: 2, relative L2 error: 10.064338%
# noise_ratio: 0.13265306122448978, repeat: 2, relative L2 error: 8.696663%
# noise_ratio: 0.14285714285714285, repeat: 2, relative L2 error: 9.431866%
# noise_ratio: 0.1530612244897959, repeat: 2, relative L2 error: 46.044105%
# noise_ratio: 0.16326530612244897, repeat: 2, relative L2 error: 50.045047%
# noise_ratio: 0.17346938775510204, repeat: 2, relative L2 error: 9.642682%
# noise_ratio: 0.18367346938775508, repeat: 2, relative L2 error: 29.848997%
# noise_ratio: 0.19387755102040816, repeat: 2, relative L2 error: 10.173806%
# noise_ratio: 0.2040816326530612, repeat: 2, relative L2 error: 11.371559%
# noise_ratio: 0.21428571428571427, repeat: 2, relative L2 error: 12.860332%
# noise_ratio: 0.22448979591836732, repeat: 2, relative L2 error: 8.946289%
# noise_ratio: 0.2346938775510204, repeat: 2, relative L2 error: 10.616008%
# noise_ratio: 0.24489795918367346, repeat: 2, relative L2 error: 119.567835%
# noise_ratio: 0.25510204081632654, repeat: 2, relative L2 error: 11.224526%
# noise_ratio: 0.26530612244897955, repeat: 2, relative L2 error: 54.910457%
# noise_ratio: 0.2755102040816326, repeat: 2, relative L2 error: 71.602060%
# noise_ratio: 0.2857142857142857, repeat: 2, relative L2 error: 52.500482%
# noise_ratio: 0.29591836734693877, repeat: 2, relative L2 error: 61.557436%
# noise_ratio: 0.3061224489795918, repeat: 2, relative L2 error: 56.508680%
# noise_ratio: 0.31632653061224486, repeat: 2, relative L2 error: 49.892987%
# noise_ratio: 0.32653061224489793, repeat: 2, relative L2 error: 71.481094%
# noise_ratio: 0.336734693877551, repeat: 2, relative L2 error: 88.235324%
# noise_ratio: 0.3469387755102041, repeat: 2, relative L2 error: 13.150019%
# noise_ratio: 0.3571428571428571, repeat: 2, relative L2 error: 57.487866%
# noise_ratio: 0.36734693877551017, repeat: 2, relative L2 error: 72.815424%
# noise_ratio: 0.37755102040816324, repeat: 2, relative L2 error: 64.678582%
# noise_ratio: 0.3877551020408163, repeat: 2, relative L2 error: 83.267102%
# noise_ratio: 0.39795918367346933, repeat: 2, relative L2 error: 115.968028%
# noise_ratio: 0.4081632653061224, repeat: 2, relative L2 error: 135.405968%
# noise_ratio: 0.4183673469387755, repeat: 2, relative L2 error: 123.924412%
# noise_ratio: 0.42857142857142855, repeat: 2, relative L2 error: 109.050785%
# noise_ratio: 0.4387755102040816, repeat: 2, relative L2 error: 151.964397%
# noise_ratio: 0.44897959183673464, repeat: 2, relative L2 error: 162.993413%
# noise_ratio: 0.4591836734693877, repeat: 2, relative L2 error: 150.689137%
# noise_ratio: 0.4693877551020408, repeat: 2, relative L2 error: 241.456157%
# noise_ratio: 0.47959183673469385, repeat: 2, relative L2 error: 169.087554%
# noise_ratio: 0.4897959183673469, repeat: 2, relative L2 error: 61.333274%
# noise_ratio: 0.5, repeat: 2, relative L2 error: 180.948464%
# noise_ratio: 0.0, repeat: 3, relative L2 error: 7.841785%
# noise_ratio: 0.01020408163265306, repeat: 3, relative L2 error: 7.925795%
# noise_ratio: 0.02040816326530612, repeat: 3, relative L2 error: 7.840916%
# noise_ratio: 0.030612244897959183, repeat: 3, relative L2 error: 7.948093%
# noise_ratio: 0.04081632653061224, repeat: 3, relative L2 error: 8.156411%
# noise_ratio: 0.0510204081632653, repeat: 3, relative L2 error: 8.000485%
# noise_ratio: 0.061224489795918366, repeat: 3, relative L2 error: 8.407388%
# noise_ratio: 0.07142857142857142, repeat: 3, relative L2 error: 8.491251%
# noise_ratio: 0.08163265306122448, repeat: 3, relative L2 error: 8.402620%
# noise_ratio: 0.09183673469387754, repeat: 3, relative L2 error: 8.161573%
# noise_ratio: 0.1020408163265306, repeat: 3, relative L2 error: 8.416271%
# noise_ratio: 0.11224489795918366, repeat: 3, relative L2 error: 9.087534%
# noise_ratio: 0.12244897959183673, repeat: 3, relative L2 error: 9.107917%
# noise_ratio: 0.13265306122448978, repeat: 3, relative L2 error: 8.356027%
# noise_ratio: 0.14285714285714285, repeat: 3, relative L2 error: 33.764972%
# noise_ratio: 0.1530612244897959, repeat: 3, relative L2 error: 8.475387%
# noise_ratio: 0.16326530612244897, repeat: 3, relative L2 error: 12.085255%
# noise_ratio: 0.17346938775510204, repeat: 3, relative L2 error: 51.139415%
# noise_ratio: 0.18367346938775508, repeat: 3, relative L2 error: 9.858263%
# noise_ratio: 0.19387755102040816, repeat: 3, relative L2 error: 10.473154%
# noise_ratio: 0.2040816326530612, repeat: 3, relative L2 error: 9.376113%
# noise_ratio: 0.21428571428571427, repeat: 3, relative L2 error: 10.084639%
# noise_ratio: 0.22448979591836732, repeat: 3, relative L2 error: 10.350865%
# noise_ratio: 0.2346938775510204, repeat: 3, relative L2 error: 52.915015%
# noise_ratio: 0.24489795918367346, repeat: 3, relative L2 error: 61.790898%
# noise_ratio: 0.25510204081632654, repeat: 3, relative L2 error: 36.950070%
# noise_ratio: 0.26530612244897955, repeat: 3, relative L2 error: 56.817012%
# noise_ratio: 0.2755102040816326, repeat: 3, relative L2 error: 58.474599%
# noise_ratio: 0.2857142857142857, repeat: 3, relative L2 error: 103.356945%
# noise_ratio: 0.29591836734693877, repeat: 3, relative L2 error: 90.425414%
# noise_ratio: 0.3061224489795918, repeat: 3, relative L2 error: 76.660032%
# noise_ratio: 0.31632653061224486, repeat: 3, relative L2 error: 14.318248%
# noise_ratio: 0.32653061224489793, repeat: 3, relative L2 error: 57.664669%
# noise_ratio: 0.336734693877551, repeat: 3, relative L2 error: 57.952436%
# noise_ratio: 0.3469387755102041, repeat: 3, relative L2 error: 74.123322%
# noise_ratio: 0.3571428571428571, repeat: 3, relative L2 error: 73.897967%
# noise_ratio: 0.36734693877551017, repeat: 3, relative L2 error: 95.273984%
# noise_ratio: 0.37755102040816324, repeat: 3, relative L2 error: 14.932141%
# noise_ratio: 0.3877551020408163, repeat: 3, relative L2 error: 121.316172%
# noise_ratio: 0.39795918367346933, repeat: 3, relative L2 error: 64.700943%
# noise_ratio: 0.4081632653061224, repeat: 3, relative L2 error: 103.601866%
# noise_ratio: 0.4183673469387755, repeat: 3, relative L2 error: 116.766025%
# noise_ratio: 0.42857142857142855, repeat: 3, relative L2 error: 175.351332%
# noise_ratio: 0.4387755102040816, repeat: 3, relative L2 error: 117.091549%
# noise_ratio: 0.44897959183673464, repeat: 3, relative L2 error: 98.274419%
# noise_ratio: 0.4591836734693877, repeat: 3, relative L2 error: 146.228737%
# noise_ratio: 0.4693877551020408, repeat: 3, relative L2 error: 75.008729%
# noise_ratio: 0.47959183673469385, repeat: 3, relative L2 error: 74.608876%
# noise_ratio: 0.4897959183673469, repeat: 3, relative L2 error: 97.432679%
# noise_ratio: 0.5, repeat: 3, relative L2 error: 122.919452%
# noise_ratio: 0.0, repeat: 4, relative L2 error: 7.866238%
# noise_ratio: 0.01020408163265306, repeat: 4, relative L2 error: 7.856177%
# noise_ratio: 0.02040816326530612, repeat: 4, relative L2 error: 7.943733%
# noise_ratio: 0.030612244897959183, repeat: 4, relative L2 error: 7.935858%
# noise_ratio: 0.04081632653061224, repeat: 4, relative L2 error: 8.160147%
# noise_ratio: 0.0510204081632653, repeat: 4, relative L2 error: 7.991282%
# noise_ratio: 0.061224489795918366, repeat: 4, relative L2 error: 8.152213%
# noise_ratio: 0.07142857142857142, repeat: 4, relative L2 error: 8.246138%
# noise_ratio: 0.08163265306122448, repeat: 4, relative L2 error: 8.696350%
# noise_ratio: 0.09183673469387754, repeat: 4, relative L2 error: 8.408550%
# noise_ratio: 0.1020408163265306, repeat: 4, relative L2 error: 8.837870%
# noise_ratio: 0.11224489795918366, repeat: 4, relative L2 error: 8.589546%
# noise_ratio: 0.12244897959183673, repeat: 4, relative L2 error: 9.299996%
# noise_ratio: 0.13265306122448978, repeat: 4, relative L2 error: 9.043477%
# noise_ratio: 0.14285714285714285, repeat: 4, relative L2 error: 8.971569%
# noise_ratio: 0.1530612244897959, repeat: 4, relative L2 error: 9.784087%
# noise_ratio: 0.16326530612244897, repeat: 4, relative L2 error: 8.972579%
# noise_ratio: 0.17346938775510204, repeat: 4, relative L2 error: 10.302708%
# noise_ratio: 0.18367346938775508, repeat: 4, relative L2 error: 39.131342%
# noise_ratio: 0.19387755102040816, repeat: 4, relative L2 error: 64.163856%
# noise_ratio: 0.2040816326530612, repeat: 4, relative L2 error: 51.862846%
# noise_ratio: 0.21428571428571427, repeat: 4, relative L2 error: 11.016011%
# noise_ratio: 0.22448979591836732, repeat: 4, relative L2 error: 12.099419%
# noise_ratio: 0.2346938775510204, repeat: 4, relative L2 error: 39.708496%
# noise_ratio: 0.24489795918367346, repeat: 4, relative L2 error: 70.373846%
# noise_ratio: 0.25510204081632654, repeat: 4, relative L2 error: 12.996609%
# noise_ratio: 0.26530612244897955, repeat: 4, relative L2 error: 74.862181%
# noise_ratio: 0.2755102040816326, repeat: 4, relative L2 error: 74.385900%
# noise_ratio: 0.2857142857142857, repeat: 4, relative L2 error: 62.834838%
# noise_ratio: 0.29591836734693877, repeat: 4, relative L2 error: 11.465568%
# noise_ratio: 0.3061224489795918, repeat: 4, relative L2 error: 87.018858%
# noise_ratio: 0.31632653061224486, repeat: 4, relative L2 error: 73.137393%
# noise_ratio: 0.32653061224489793, repeat: 4, relative L2 error: 13.329574%
# noise_ratio: 0.336734693877551, repeat: 4, relative L2 error: 15.583937%
# noise_ratio: 0.3469387755102041, repeat: 4, relative L2 error: 131.517195%
# noise_ratio: 0.3571428571428571, repeat: 4, relative L2 error: 72.799820%
# noise_ratio: 0.36734693877551017, repeat: 4, relative L2 error: 97.838462%
# noise_ratio: 0.37755102040816324, repeat: 4, relative L2 error: 133.886565%
# noise_ratio: 0.3877551020408163, repeat: 4, relative L2 error: 83.716827%
# noise_ratio: 0.39795918367346933, repeat: 4, relative L2 error: 107.293020%
# noise_ratio: 0.4081632653061224, repeat: 4, relative L2 error: 122.089914%
# noise_ratio: 0.4183673469387755, repeat: 4, relative L2 error: 157.430449%
# noise_ratio: 0.42857142857142855, repeat: 4, relative L2 error: 99.571586%
# noise_ratio: 0.4387755102040816, repeat: 4, relative L2 error: 97.647100%
# noise_ratio: 0.44897959183673464, repeat: 4, relative L2 error: 70.385638%
# noise_ratio: 0.4591836734693877, repeat: 4, relative L2 error: 157.416368%
# noise_ratio: 0.4693877551020408, repeat: 4, relative L2 error: 15.517380%
# noise_ratio: 0.47959183673469385, repeat: 4, relative L2 error: 100.287512%
# noise_ratio: 0.4897959183673469, repeat: 4, relative L2 error: 68.834035%
# noise_ratio: 0.5, repeat: 4, relative L2 error: 169.664075%
